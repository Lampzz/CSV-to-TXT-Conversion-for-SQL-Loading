# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Mukuna\\Downloads\\Covid-19\\CovidVaccinations.csv')
df.head()
# Out:
#   iso_code continent     location        date  new_tests  total_tests  \
# 0      AFG      Asia  Afghanistan  2020-02-24        NaN          NaN
# 1      AFG      Asia  Afghanistan  2020-02-25        NaN          NaN
# 2      AFG      Asia  Afghanistan  2020-02-26        NaN          NaN
# 3      AFG      Asia  Afghanistan  2020-02-27        NaN          NaN
# 4      AFG      Asia  Afghanistan  2020-02-28        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  ...  gdp_per_capita  extreme_poverty  \
# ...

# %%
df.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 4111
# location                                     0
# date                                         0
# new_tests                                46226
# total_tests                              46519
# total_tests_per_thousand                 46519
# new_tests_per_thousand                   46226
# new_tests_smoothed                       40546
# new_tests_smoothed_per_thousand          40546
# positive_rate                            42267
# tests_per_case                           42860
# tests_units                              39092
# total_vaccinations                       75797
# people_vaccinated                        76427
# people_fully_vaccinated                  78740
# new_vaccinations                         77217
# new_vaccinations_smoothed                70079
# total_vaccinations_per_hundred           75797
# people_vaccinated_per_hundred            76427
# ...

# %%
df.dtypes
# Out:
# iso_code                                         object
# continent                                        object
# location                                         object
# date                                     datetime64[ns]
# new_tests                                       float64
# total_tests                                     float64
# total_tests_per_thousand                        float64
# new_tests_per_thousand                          float64
# new_tests_smoothed                              float64
# new_tests_smoothed_per_thousand                 float64
# positive_rate                                   float64
# tests_per_case                                  float64
# tests_units                                      object
# total_vaccinations                              float64
# people_vaccinated                               float64
# people_fully_vaccinated                         float64
# new_vaccinations                                float64
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
y = []

for i in range(len(df)):
    x = tuple(df.iloc[i])
    y.append(x)

y
# Out:
# [('AFG',
#   'Asia',
#   'Afghanistan',
#   Timestamp('2020-02-24 00:00:00'),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   8.33,
#   54.422,
#   18.6,
#   2.581,
#   1.337,
#   1803.987,
#   nan,
#   597.029,
#   9.59,
#   nan,
#   nan,
#   37.746,
#   0.5,
#   64.83,
#   0.511),
#  ('AFG',
#   'Asia',
#   'Afghanistan',
#   Timestamp('2020-02-25 00:00:00'),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   8.33,
#   54.422,
#   18.6,
#   2.581,
#   1.337,
#   1803.987,
#   nan,
#   597.029,
#   9.59,
#   nan,
#   nan,
#   37.746,
#   0.5,
#   64.83,
#   0.511),
#  ('AFG',
#   'Asia',
#   'Afghanistan',
#   Timestamp('2020-02-26 00:00:00'),
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
# ...

# %%
file = open('C:\\Users\\Mukuna\\Downloads\\Covid_Vaccinations.txt', 'w')
for tuple in y:
    file.write(str(tuple) + ',' + '\n')
file.close()
